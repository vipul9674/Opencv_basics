# %%
import cv2

# %%
image = cv2.imread('barca.jpg')

# %%
# if image =cv2.imread('barca.jpg',0) this will make picture black&white

# %%
print(image)
# Out:
# [[ 4  5  7 ...  8 17 23]
#  [ 4  5  7 ...  7 14 19]
#  [ 4  5  7 ...  5 10 13]
#  ...
#  [ 6  7  9 ...  3  3  3]
#  [ 8  7  7 ...  3  4  4]
#  [ 9  7  5 ...  4  4  4]]

# %%
print(image.shape)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
cv2.imshow('Barca Frame',image)
cv2.waitKey(0)
# Out:
# -1

# %%
cap = cv2.VideoCapture(0)

while True:
    flag, frame = cap.read()
    if not flag:
        print("could not access the camera")
        break
    cv2.imshow('frame', frame)
    k = cv2.waitkey(1)
    if k==ord('q'):
        break
    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-be35db6fc01c> in <module>
# ----> 1 cap = cv2.VideoCapture(0)
#       2
#       3 while True:
#       4     flag, frame = cap.read()
#       5     if not flag:
#
# NameError: name 'cv2' is not defined
