# %%
import cv2
import matplotlib.pyplot as plt

image =cv2.imread('barca.jpg')
print(image)
# Out:
# [[[ 0  0 17]
#   [ 0  0 18]
#   [ 2  1 21]
#   ...
#   [15  9  4]
#   [24 18 13]
#   [30 24 19]]
#
#  [[ 0  0 17]
#   [ 0  0 18]
#   [ 2  1 21]
#   ...
#   [14  8  3]
#   [21 15 10]
#   [26 20 15]]
#
#  [[ 0  0 17]
#   [ 0  0 18]
#   [ 2  1 21]
#   ...
#   [12  6  1]
#   [17 11  6]
#   [20 14  9]]
#
#  ...
#
#  [[ 2  0 20]
#   [ 3  1 21]
#   [ 5  2 24]
#   ...
#   [ 7  4  0]
#   [ 7  4  0]
#   [ 7  4  0]]
#
#  [[ 4  1 23]
#   [ 3  0 22]
#   [ 3  0 24]
#   ...
#   [ 7  4  0]
#   [ 8  5  1]
#   [ 8  5  1]]
#
#  [[ 5  2 24]
#   [ 3  0 22]
#   [ 1  0 22]
#   ...
#   [ 8  5  1]
#   [ 8  5  1]
#   [ 8  5  1]]]

# %%
print(image.shape)
# Out:
# (1600, 2560, 3)

# %%
gray_img= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.title("Grayed Image")
plt.imshow(cv2.cvtColor(gray_img,cv2.COLOR_BGR2RGB))

plt.subplot(1,2,2)
plt.title("Grayed Image")
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))

plt.show()

# %%
import numpy as np
zeros = np.zeros((image.shape[0],image.shape[1]),np.uint8)
b,g,r = cv2.split(image)
print("Blue Channel:" , b)
print("Green Channel:" , g)
print("Red Channel:" , r)
cv2.imshow("Blue",b)
# Out:
# Blue Channel: [[ 0  0  2 ... 15 24 30]
#  [ 0  0  2 ... 14 21 26]
#  [ 0  0  2 ... 12 17 20]
#  ...
#  [ 2  3  5 ...  7  7  7]
#  [ 4  3  3 ...  7  8  8]
#  [ 5  3  1 ...  8  8  8]]
# Green Channel: [[ 0  0  1 ...  9 18 24]
#  [ 0  0  1 ...  8 15 20]
#  [ 0  0  1 ...  6 11 14]
#  ...
#  [ 0  1  2 ...  4  4  4]
#  [ 1  0  0 ...  4  5  5]
#  [ 2  0  0 ...  5  5  5]]
# Red Channel: [[17 18 21 ...  4 13 19]
#  [17 18 21 ...  3 10 15]
#  [17 18 21 ...  1  6  9]
#  ...
#  [20 21 24 ...  0  0  0]
#  [23 22 24 ...  0  1  1]
#  [24 22 22 ...  1  1  1]]
